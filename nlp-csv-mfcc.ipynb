# %% [markdown]
# # Part 1 - Feature Extraction (from WAV using MFCC)
# Mel Frequency Capstral Coefficients

# %%
import os
import librosa
import csv
import numpy as np
import pandas as pd

import librosa
import librosa.display

# %% [markdown]
# ### Installation of required libraries

# %%
# !pip install samplerate
# !pip install resampy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 663.0 kB/s eta 0:00:0000:0100:05
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 26.7 MB/s eta 0:00:0000:0100:01
# ...

# %% [markdown]
# <h1> Feature Extraction: 30 MFCCs </h1>

# %%
path = '/kaggle/input/maestro-raw/'  # replace with the path to actual directory
lst = []
for subdir, dirs, files in os.walk(path):
    for file in files:
        try:
            # Load librosa array, obtain mfccs, store the file and the mcss information in a new array
            X, sample_rate = librosa.load(os.path.join(subdir, file), res_type='kaiser_fast', sr=None)
            mfccs = np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=30).T, axis=0)
            arr = [file] + mfccs.tolist()  # combine the file ID and the MFCCs
            lst.append(arr)

        except ValueError:
            continue

# Writing to csv file
csv_file_path = 'output30.csv'
with open(csv_file_path, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['File_ID'] + [f'MFCC_{i}' for i in range(1, 31)])  # write header
    writer.writerows(lst)

print(f"CSV file has been saved to {csv_file_path}")
# Out:
# CSV file has been saved to output30.csv
